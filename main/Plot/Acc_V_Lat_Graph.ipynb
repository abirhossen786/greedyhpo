# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

# %%
x1 = np.array([0.238,0.230,0.228])
y1 = np.array([0.800,0.786,0.738])

x2 = np.array([0.242,0.234,0.232])
y2 = np.array([0.798,0.784,0.740])

x3= np.array([0.235,0.227,0.218])
y3 = np.array([0.796,0.784,0.734])

# %%
x4 = np.array([0.239,0.239,0.236])
y4 = np.array([0.712,0.602,0.674])

x5 = np.array([0.244,0.242,0.242])
y5 = np.array([0.710,0.598,0.678])

x6 = np.array([0.237,0.237,0.234])
y6 = np.array([0.712,0.600,0.666])

# %%
x7 = np.array([0.252,0.249,0.244])
y7 = np.array([0.83,0.802,0.766])

x8 = np.array([0.254,0.252,0.247])
y8 = np.array([0.83,0.798,0.806])

x9 = np.array([0.249,0.247,0.242])
y9 = np.array([0.832,0.764,0.766])

# %%
x10 = np.array([0.245,0.241,0.237])
y10 = np.array([0.656,0.52,0.67])

x11 = np.array([0.245,0.244,0.240])
y11 = np.array([0.654,0.516,0.67])

x12 = np.array([0.242,0.239,0.235])
y12 = np.array([0.65,0.51,0.67])

# %%
x13 = np.array([0.247,0.239,0.236])
y13 = np.array([0.797,0.783,0.74])

x14 = np.array([0.247,0.245,0.244])
y14 = np.array([0.709,0.597,0.677])

# %%
x15 = np.array([0.260,0.257,0.252])
y15 = np.array([0.829,0.797,0.763])

x16 = np.array([0.253,0.249,0.245])
y16 = np.array([0.653,0.515,0.671])

# %%
#axs[0].figure(figsize=(35,20), dpi=500)
fig, axs = plt.subplots(2,figsize=(7.5,6.5))
#fig.suptitle('Accuracy Vs Latency')
axs[0].set_title('CIFAR10',fontsize = 16)
axs[0].set_xlabel('Accuracy (%)',fontsize = 12.5)
axs[0].set_ylabel('Latency(s)',fontsize = 12.5)

ms = 7
axs[0].plot( y13[0],x13[0], 'X',fillstyle='none',c='k',label='VGG16-w/o Quant-BO',markersize=ms)
axs[0].plot( y13[1],x13[1], 'X',fillstyle='none',c='yellowgreen',label='VGG16-w/o Quant-RS',markersize=ms)
axs[0].plot( y13[2],x13[2], 'X',fillstyle='none',c='teal',label='VGG16-w/o Quant-GHO',markersize=ms)

axs[0].plot( y2[0],x2[0], 'o',fillstyle='none',c='k',label='VGG16-FP16-BO',markersize=ms)
axs[0].plot( y2[1],x2[1], 'o',fillstyle='none',c='yellowgreen',label='VGG16-FP16-RS',markersize=ms)
axs[0].plot( y2[2],x2[2], 'o',fillstyle='none',c='teal',label='VGG16-FP16-GHO',markersize=ms)

axs[0].plot(y1[0],x1[0], 'd',fillstyle='none',c='k',label='VGG16-DR-BO',markersize=ms)
axs[0].plot(y1[1],x1[1], 'd',fillstyle='none',c='yellowgreen',label='VGG16-DR-RS',markersize=ms)
axs[0].plot(y1[2],x1[2], 'd',fillstyle='none',c='teal',label='VGG16-DR-GHO',markersize=ms)

axs[0].plot( y3[0],x3[0], '*',fillstyle='none',c='k',label='VGG16-INT8-BO',markersize=ms)
axs[0].plot( y3[1],x3[1], '*',fillstyle='none',c='yellowgreen',label='VGG16-INT8-RS',markersize=ms)
axs[0].plot( y3[2],x3[2], '*',fillstyle='none',c='teal',label='VGG16-INT8-GHO',markersize=ms)

axs[0].plot( y14[0],x14[0], 'X',fillstyle='none',c='red',label='RESNET50-w/o Quant-BO',markersize=ms)
axs[0].plot( y14[1],x14[1], 'X',fillstyle='none',c='indigo',label='RESNET50-w/o Quant-RS',markersize=ms)
axs[0].plot( y14[2],x14[2], 'X',fillstyle='none',c='coral',label='RESNET0-w/o Quant-GHO',markersize=ms)

axs[0].plot( y5[0],x5[0], 'o',fillstyle='none',c='red',label='RESNET50-FP16-BO',markersize=ms)
axs[0].plot( y5[1],x5[1], 'o',fillstyle='none',c='indigo',label='RESNET50-FP16-RS',markersize=ms)
axs[0].plot( y5[2],x5[2], 'o',fillstyle='none',c='coral',label='RESNET50-FP16-GHO',markersize=ms)

axs[0].plot( y4[0],x4[0], 'd',fillstyle='none',c='red',label='RESNET50-DR-BO',markersize=ms)
axs[0].plot( y4[1],x4[1], 'd',fillstyle='none',c='indigo',label='RESNET50-DR-RS',markersize=ms)
axs[0].plot( y4[2],x4[2], 'd',fillstyle='none',c='coral',label='RESNET50-DR-GHO',markersize=ms)

axs[0].plot( y6[0],x6[0], '*',fillstyle='none',c='red',label='RESNET50-INT8-BO',markersize=ms)
axs[0].plot( y6[1],x6[1], '*',fillstyle='none',c='indigo',label='RESNET50-INT8-RS',markersize=ms)
axs[0].plot( y6[2],x6[2], '*',fillstyle='none',c='coral',label='RESNET0-INT8-GHO',markersize=ms)


axs[0].legend(
    loc="lower left", 
    ncol=4,
    bbox_to_anchor=[-0.14, 1.15],
    borderaxespad=0.8,
    prop = {'size':8.2}
)
axs[0].grid(linestyle = '--', linewidth = 0.5,)

axs[1].set_title('Intel',fontsize = 16)

axs[1].plot( y7[0],x7[0], 'd',fillstyle='none',c='k',markersize=ms)
axs[1].plot( y7[1],x7[1], 'd',fillstyle='none',c='yellowgreen',markersize=ms)
axs[1].plot( y7[2],x7[2], 'd',fillstyle='none',c='teal',markersize=ms)

axs[1].plot( y8[0],x8[0], 'o',fillstyle='none',c='k',markersize=ms)
axs[1].plot( y8[1],x8[1], 'o',fillstyle='none',c='yellowgreen',markersize=ms)
axs[1].plot( y8[2],x8[2], 'o',fillstyle='none',c='teal',markersize=ms)

axs[1].plot( y9[0],x9[0], '*',fillstyle='none',c='k',markersize=ms)
axs[1].plot( y9[1],x9[1], '*',fillstyle='none',c='yellowgreen',markersize=ms)
axs[1].plot( y9[2],x9[2], '*',fillstyle='none',c='teal',markersize=ms)

axs[1].plot( y15[0],x15[0], 'X',fillstyle='none',c='k',markersize=ms)
axs[1].plot( y15[1],x15[1], 'X',fillstyle='none',c='yellowgreen',markersize=ms)
axs[1].plot( y15[2],x15[2], 'X',fillstyle='none',c='teal',markersize=ms)

axs[1].plot( y10[0],x10[0], 'd',fillstyle='none',c='red',markersize=ms)
axs[1].plot( y10[1],x10[1], 'd',fillstyle='none',c='indigo',markersize=ms)
axs[1].plot( y10[2],x10[2], 'd',fillstyle='none',c='coral',markersize=ms)

axs[1].plot( y11[0],x11[0], 'o',fillstyle='none',c='red',markersize=ms)
axs[1].plot( y11[1],x11[1], 'o',fillstyle='none',c='indigo',markersize=ms)
axs[1].plot( y11[2],x11[2], 'o',fillstyle='none',c='coral',markersize=ms)

axs[1].plot( y12[0],x12[0], '*',fillstyle='none',c='red',markersize=ms)
axs[1].plot( y12[1],x12[1], '*',fillstyle='none',c='indigo',markersize=ms)
axs[1].plot( y12[2],x12[2], '*',fillstyle='none',c='coral',markersize=ms)

axs[1].plot( y16[0],x16[0], 'X',fillstyle='none',c='red',markersize=ms)
axs[1].plot( y16[1],x16[1], 'X',fillstyle='none',c='indigo',markersize=ms)
axs[1].plot( y16[2],x16[2], 'X',fillstyle='none',c='coral',markersize=ms)

axs[0].set_xlim(0.5, 0.85)
axs[1].set_xlim(0.5, 0.85)
axs[0].set_ylim(0.215, 0.265)
axs[1].set_ylim(0.215, 0.265)

axs[1].set_xlabel('Accuracy (%)',fontsize = 12.5)
axs[1].set_ylabel('Latency(s)',fontsize = 12.5)

axs[0].tick_params(axis='both', which='major', labelsize=10)
axs[0].tick_params(axis='both', which='minor', labelsize=10)

axs[1].tick_params(axis='both', which='major', labelsize=10)
axs[1].tick_params(axis='both', which='minor', labelsize=10)

axs[1].grid(linestyle = '--', linewidth = 0.5)
fig.tight_layout(pad=.9)
plt.savefig("Acc_V_Lat.pdf",dpi=100)
plt.show()
