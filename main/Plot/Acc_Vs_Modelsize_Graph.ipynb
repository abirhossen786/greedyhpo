# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

# %%
x1 = np.array([9.1,11,3.4])
y1 = np.array([0.800,0.786,0.738])

x2 = np.array([18,11,6.7])
y2 = np.array([0.798,0.784,0.740])

x3= np.array([9.2,11,3.5])
y3 = np.array([0.796,0.784,0.734])

# %%
x4 = np.array([6.7,2.9,1.4])
y4 = np.array([0.712,0.602,0.674])

x5 = np.array([13,2.9,2.5])
y5 = np.array([0.710,0.598,0.678])

x6 = np.array([6.8,3.0,1.5])
y6 = np.array([0.712,0.600,0.666])

# %%
x7 = np.array([28,4.1,2.5])
y7 = np.array([0.83,0.802,0.766])

x8 = np.array([55,4.1,4.8])
y8 = np.array([0.83,0.798,0.806])

x9 = np.array([28,4.2,2.5])
y9 = np.array([0.832,0.764,0.766])

# %%
x10 = np.array([9.1,1.4,0.85])
y10 = np.array([0.656,0.52,0.67])

x11 = np.array([18,1.4,1.5])
y11 = np.array([0.654,0.516,0.67])

x12 = np.array([6.8,3.0,1.5])
y12 = np.array([0.65,0.51,0.67])

# %%
x13 = np.array([113.9,135.4,42.8])
y13 = np.array([0.797,0.783,0.74])

x14 = np.array([85.5,37.9,19.9])
y14 = np.array([0.709,0.597,0.677])

# %%
x15 = np.array([344.3,51.5,30.7])
y15 = np.array([0.829,0.797,0.763])

x16 = np.array([115.9,19.6,13.7])
y16 = np.array([0.653,0.515,0.671])

# %%
#legend_elements = [Line2D([0], [0], marker='d', color='w', label='VGG16-DR-BO',markerfacecolor='k',fillstyle='none', markersize=15)]

# %%
#axs[0].figure(figsize=(35,20), dpi=500)
fig, axs = plt.subplots(2,figsize=(7.5,6.5))
#fig.suptitle('Model Size Vs Accuracy')
axs[0].set_title('CIFAR10',fontsize = 16)
axs[0].set_ylabel('Accuracy (%)',fontsize = 12.5)
axs[0].set_xlabel('Model Size in MB',fontsize = 12.5)

ms=7

axs[0].plot(x13[0], y13[0], 'X',fillstyle='none',c='k',label='VGG16-w/o Quant-BO',markersize=ms)
axs[0].plot(x13[1], y13[1], 'X',fillstyle='none',c='yellowgreen',label='VGG16-w/o Quant-RS',markersize=ms)
axs[0].plot(x13[2], y13[2], 'X',fillstyle='none',c='teal',label='VGG16-w/o Quant-GHO',markersize=ms)

axs[0].plot(x2[0], y2[0], 'o',fillstyle='none',c='k',label='VGG16-FP16-BO',markersize=ms)
axs[0].plot(x2[1], y2[1], 'o',fillstyle='none',c='yellowgreen',label='VGG16-FP16-RS',markersize=ms)
axs[0].plot(x2[2], y2[2], 'o',fillstyle='none',c='teal',label='VGG16-FP16-GHO',markersize=ms)

axs[0].plot(x1[0], y1[0], 'd',fillstyle='none',c='k',label='VGG16-DR-BO',markersize=ms)
axs[0].plot(x1[1], y1[1], 'd',fillstyle='none',c='yellowgreen',label='VGG16-DR-RS',markersize=ms)
axs[0].plot(x1[2], y1[2], 'd',fillstyle='none',c='teal',label='VGG16-DR-GHO',markersize=ms)


axs[0].plot(x3[0], y3[0], '*',fillstyle='none',c='k',label='VGG16-INT8-BO',markersize=ms)
axs[0].plot(x3[1], y3[1], '*',fillstyle='none',c='yellowgreen',label='VGG16-INT8-RS',markersize=ms)
axs[0].plot(x3[2], y3[2], '*',fillstyle='none',c='teal',label='VGG16-INT8-GHO',markersize=ms)



axs[0].plot(x14[0], y14[0], 'X',fillstyle='none',c='red',label='RESNET50-w/o Quant-BO',markersize=ms)
axs[0].plot(x14[1], y14[1], 'X',fillstyle='none',c='indigo',label='RESNET50-w/o Quant-RS',markersize=ms)
axs[0].plot(x14[2], y14[2], 'X',fillstyle='none',c='coral',label='RESNET0-w/o Quant-GHO',markersize=ms)

axs[0].plot(x5[0], y5[0], 'o',fillstyle='none',c='red',label='RESNET50-FP16-BO',markersize=ms)
axs[0].plot(x5[1], y5[1], 'o',fillstyle='none',c='indigo',label='RESNET50-FP16-RS',markersize=ms)
axs[0].plot(x5[2], y5[2], 'o',fillstyle='none',c='coral',label='RESNET50-FP16-GHO',markersize=ms)

axs[0].plot(x4[0], y4[0], 'd',fillstyle='none',c='red',label='RESNET50-DR-BO',markersize=ms)
axs[0].plot(x4[1], y4[1], 'd',fillstyle='none',c='indigo',label='RESNET50-DR-RS',markersize=ms)
axs[0].plot(x4[2], y4[2], 'd',fillstyle='none',c='coral',label='RESNET50-DR-GHO',markersize=ms)

axs[0].plot(x6[0], y6[0], '*',fillstyle='none',c='red',label='RESNET50-INT8-BO',markersize=ms)
axs[0].plot(x6[1], y6[1], '*',fillstyle='none',c='indigo',label='RESNET50-INT8-RS',markersize=ms)
axs[0].plot(x6[2], y6[2], '*',fillstyle='none',c='coral',label='RESNET0-INT8-GHO',markersize=ms)



axs[0].legend(
    loc="lower left", 
    ncol=4,
    bbox_to_anchor=[-0.14, 1.15],
    borderaxespad=0.8,
    prop = {'size':8.2}
)
axs[0].grid(linestyle = '--', linewidth = 0.5)

axs[1].set_title('Intel',fontsize = 16)

axs[1].plot(x7[0], y7[0], 'd',fillstyle='none',c='k',markersize=ms)
axs[1].plot(x7[1], y7[1], 'd',fillstyle='none',c='yellowgreen',markersize=ms)
axs[1].plot(x7[2], y7[2], 'd',fillstyle='none',c='teal',markersize=ms)

axs[1].plot(x8[0], y8[0], 'o',fillstyle='none',c='k',markersize=ms)
axs[1].plot(x8[1], y8[1], 'o',fillstyle='none',c='yellowgreen',markersize=ms)
axs[1].plot(x8[2], y8[2], 'o',fillstyle='none',c='teal',markersize=ms)

axs[1].plot(x9[0], y9[0], '*',fillstyle='none',c='k',markersize=ms)
axs[1].plot(x9[1], y9[1], '*',fillstyle='none',c='yellowgreen',markersize=ms)
axs[1].plot(x9[2], y9[2], '*',fillstyle='none',c='teal',markersize=ms)

axs[1].plot(x15[0], y15[0], 'X',fillstyle='none',c='k',markersize=ms)
axs[1].plot(x15[1], y15[1], 'X',fillstyle='none',c='yellowgreen',markersize=ms)
axs[1].plot(x15[2], y15[2], 'X',fillstyle='none',c='teal',markersize=ms)

axs[1].plot(x10[0], y10[0], 'd',fillstyle='none',c='red',markersize=ms)
axs[1].plot(x10[1], y10[1], 'd',fillstyle='none',c='indigo',markersize=ms)
axs[1].plot(x10[2], y10[2], 'd',fillstyle='none',c='coral',markersize=ms)

axs[1].plot(x11[0], y11[0], 'o',fillstyle='none',c='red',markersize=ms)
axs[1].plot(x11[1], y11[1], 'o',fillstyle='none',c='indigo',markersize=ms)
axs[1].plot(x11[2], y11[2], 'o',fillstyle='none',c='coral',markersize=ms)

axs[1].plot(x12[0], y12[0], '*',fillstyle='none',c='red',markersize=ms)
axs[1].plot(x12[1], y12[1], '*',fillstyle='none',c='indigo',markersize=ms)
axs[1].plot(x12[2], y12[2], '*',fillstyle='none',c='coral',markersize=ms)

axs[1].plot(x16[0], y16[0], 'X',fillstyle='none',c='red',markersize=ms)
axs[1].plot(x16[1], y16[1], 'X',fillstyle='none',c='indigo',markersize=ms)
axs[1].plot(x16[2], y16[2], 'X',fillstyle='none',c='coral',markersize=ms)

axs[1].set_ylabel('Accuracy (%)',fontsize = 12.5)
axs[1].set_xlabel('Model Size in MB',fontsize = 12.5)
axs[1].grid(linestyle = '--', linewidth = 0.5)

# axs[0].set_xlim(0,350)
# axs[1].set_xlim(0, 350)
axs[0].set_ylim(0.50, 0.85)
axs[1].set_ylim(0.50, 0.85)

start, end = axs[0].get_xlim()
axs[0].xaxis.set_ticks(np.arange(0, 160, 20))
axs[1].xaxis.set_ticks(np.arange(0, 360, 20))

axs[0].tick_params(axis='both', which='major', labelsize=12)
axs[0].tick_params(axis='both', which='minor', labelsize=12)

axs[1].tick_params(axis='both', which='major', labelsize=11)
axs[1].tick_params(axis='both', which='minor', labelsize=11)

fig.tight_layout(pad=.9)
plt.savefig("Acc_V_Size.pdf",dpi=100)
plt.show()
